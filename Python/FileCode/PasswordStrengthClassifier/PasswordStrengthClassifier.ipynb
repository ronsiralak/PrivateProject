# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
csv_file = 'data.csv'
df = pd.read_csv(csv_file, on_bad_lines='skip')
df.head()
# Out:
#       password  strength
# 0     kzde5577         1
# 1     kino3434         1
# 2    visi7k1yr         1
# 3     megzy123         1
# 4  lamborghin1         1

# %%
df = df.dropna()
df["strength"] = df["strength"].map({0: "Weak",
                                         1: "Medium",
                                         2: "Strong"})
df.sample(5)
# Out:
# <ipython-input-3-0b00163e4934>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["strength"] = df["strength"].map({0: "Weak",
#           password strength
# 663190  libraole68   Medium
# 3898     jrsblora1   Medium
# 469353   M13ATMOON   Medium
# 374541     fmdi56u     Weak
# 434172    schud6e2   Medium

# %%
def word(password):
    character=[]
    for i in password:
        character.append(i)
    return character

x = np.array(df["password"])
y = np.array(df["strength"])

tdif = TfidfVectorizer(tokenizer=word)
x = tdif.fit_transform(x)
xtrain, xtest, ytrain, ytest = train_test_split(x, y,
                                                test_size=0.05,
                                                random_state=42)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
model = RandomForestClassifier()
model.fit(xtrain, ytrain)
print(model.score(xtest, ytest))
# Out:
# 0.9560659458813691

# %%
import joblib
from sklearn.datasets import load_iris
model_filename = 'PasswordModel.pkl'
joblib.dump(model, model_filename)
# Out:
# ['PasswordModel.pkl']

# %%
# To load the model from the file later:
loaded_model = joblib.load(model_filename)

# %%
import getpass
user = getpass.getpass("Enter Password: ")
data = tdif.transform([user]).toarray()
output = loaded_model.predict(data)
print(output)
# Out:
# Enter Password: ··········
# ['Strong']
